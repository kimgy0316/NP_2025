# %% [markdown]
# ## 9장 노트정리
#
# 이 파일은 9장 연습문제이다.
#
# 날짜 : 2025.10.14
#
# 작성자 : 김경연 (202311383)

# %% [markdown]
# #### 연습문제(1)
# #### WSL2 를 Windows 환경에 설치하고 Ubuntu 최신 버전을 MS Store 에서 찾아 설치하라.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 연습문제(2)
# #### Ubuntu 가상머신을 실행하고 IP, Netmask를 확인하라.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 연습문제(3)
# #### Windows 호스트머신과 Ubuntu 가상머신과 통신이 되는지 확인하라.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 연습문제(4)
# #### Mobaxterm으로 Ubuntu 에 접속하라.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 연습문제(5)
# #### 호스트머신 VS code 를 띄워서 WSL Ubuntu에 접속하고 폴더를 열어라.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 연습문제(6)
# #### 간단한 리눅스 명령어를 실습하라.
#
# ![image.png](attachment:image.png)
