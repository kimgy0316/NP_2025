# %% [markdown]
# ## 3장 노트정리
#
# 이 파일은 3장을 학습하면서 실행한 내용을 정리한 것이다.
#
# 날짜 : 2025.9.16
#
# 작성자 : 김경연 (202311383)

# %% [markdown]
# ## 03. 프로그램의 제어문

# %% [markdown]
# 프로그램의 실행 순서를 바꾸는 문장
#
# 1) 조건문
#    if, if-else, if-elif-else
#
# 2) 반복문
#     while, for
#
# 3) 기타 제어문
#    break, continue

# %% [markdown]
# 1) 조건문 (if 제어문)
#
# 1-1) if문
# ![image.png](attachment:image.png)

# %% [markdown]
# 1-2) if-else문
# ![image.png](attachment:image.png)
#
#
# 아래 거에 더 익숙해져야 함.(파이썬 스타일)
# >> *** 실습할 때 3번 쳐보기 ***
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 가독성 vs 효율성

# %% [markdown]
# 1-3) 중첩 if문-if문 속에 또 다른 if문
# ![image.png](attachment:image.png)

# %% [markdown]
# 2) 반복문 (while 반복문)

# %% [markdown]
# 1-1) while문
# ![image.png](attachment:image.png)
#
# *** // ***

# %% [markdown]
# 3) 제어문 (for)
#
# *** C와 쓰는 방법이 약간 다름 ***

# %% [markdown]
# 3-1) for문
#
# listx = [ 1, 4, 1, 5, 3]
#
# (모든 객체가 올 수 있음.)
#
# >> 순서 있는 객체들의 모임.
#
# >> 주의사항 : list2 = listx (포인트임./카피 안됨/주소다름)
#
# >> list3 = list(listx) = listx.copy()
#    (shallow copy, deep copy)
#    *** 찾아보기 ***

# %% [markdown]
# *** 4가지 중요 ***
#
# listx = [ 1, 2, 5, 7 ,3 ]
#
# setx = { 'a', 'b', 'c', 'd' }
#
# tuple = ( 'xyz', 3 )
#
# dict??? = { 'k1':3, 'k2':4 }

# %% [markdown]
# list
# ![image.png](attachment:image.png)

# %% [markdown]
# 튜플
# ![image.png](attachment:image.png)

# %% [markdown]
# 문자열
# ![image.png](attachment:image.png)
