# %% [markdown]
# ## 5장 노트정리
#
# 이 파일은 5장을 학습하면서 실행한 내용을 정리한 것이다.
#
# 날짜 : 2025.9.16
#
# 작성자 : 김경연 (202311383)

# %% [markdown]
# 5. 함수

# %% [markdown]
# 함수를 사용하는 이유
# 1) 프로그램 안에서 중복된 코드를 제거한다.
# 2) 복잡한 프로그래밍 작업을 더 간단한 작업들로 분해할 수 있다.
# 3) 함수는 한 번 만들어지면 다름 프로그램에서도 재사용될 수 있다.
# 4) 함수를 사용하면 가독성(프로그램의 이해)이 증대되고, 유지 관리도 쉬워진다.

# %% [markdown]
# 아래는 자바 스타일의 코드
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 파이썬은 주로 fstring을 사용
#
# *** 찾아보기 ***

# %% [markdown]
# *** 가변 매개변수 ***
#
# def f(*args)

# %% [markdown]
# keys
# :

# %% [markdown]
# *** 중요하게 공부 ***
#
# ![image.png](attachment:image.png)
